# %%
import pandas as pd
import numpy as np
import spacy
nlp = spacy.load("en_core_web_sm")
import json
from spacy.lemmatizer import Lemmatizer, ADJ, NOUN, VERB

lemmatizer = nlp.vocab.morphology.lemmatizer

# %%
import numpy as np
import operator
fileList=['GPTBaseline']
resultDf=pd.DataFrame()
for num,fileName in enumerate(fileList):
    print(fileName)
    dfs=pd.read_excel("FinalDatasetAuto"+fileName+".xlsx",index_col=0)
    dfs=dfs[0:427]
    for index,i in enumerate(dfs['adj/noun']):
        if dfs.loc[index,'adj/noun-label']=='A' and (dfs.loc[index,'adverb']=='X' or pd.isnull(dfs.loc[index,'adverb'])):
            dfs.loc[index,'arg0']=''
            dfs.loc[index,'arg1']=''
            dfs.loc[index,'V']=''
            dfs.loc[index,'baseV']=''
            dfs.loc[index,'PP']=''
    dfs['arg0']=dfs['arg0'].replace(np.NaN,'')
    dfs['arg1']=dfs['arg1'].replace(np.NaN,'')
    dfs['PP']=dfs['PP'].replace(np.NaN,'')
    dfs['adverb']=dfs['adverb'].replace(np.NaN,'')
    columnList=['arg0','baseV','arg1','PP','adverb']
    for index,i in enumerate(dfs['adj/noun']):
        result=''
        for column in columnList:
            if dfs.loc[index,column]!='' and dfs.loc[index,column]!='X':
                    result=result+dfs.loc[index,column]+" "
        dfs.loc[index,'gold']=result.strip()
    for index,i in enumerate(dfs['adj/noun']):
        if index+1<len(dfs['adj/noun']) and dfs.loc[index,'adj/noun']==dfs.loc[index+1,'adj/noun'] and dfs.loc[index,'n_v']==dfs.loc[index+1,'n_v'] and dfs.loc[index,'prep']==dfs.loc[index+1,'prep'] and dfs.loc[index,'pobj']==dfs.loc[index+1,'pobj']:
            dfs.loc[index,'gold2']=dfs.loc[index+1,'gold']
        else:
            dfs.loc[index,'gold2']=dfs.loc[index,'gold']
    for index,i in enumerate(dfs['gold']):
        if not pd.isnull(i):
            doc=nlp(i)
            reducedGold=''
            for word in doc:
                if word.tag_!='DT':
                        reducedGold=reducedGold+word.lemma_+" "
            dfs.loc[index,'reducedGold']=reducedGold.lower()
            reducedGold3=''
            for para in dfs.loc[index,'gold'].split():
                doc=nlp(para)
                for word in doc:
                    if word.tag_!='DT':
                        if word.text!='a' and word.text!='an' and word.text!='the':
                            answer=lemmatizer(word.text, NOUN)
                            reducedGold3=reducedGold3+answer[0]+" "
            dfs.loc[index,'reducedGold3']=reducedGold3.lower()
    for index,i in enumerate(dfs['gold2']):
        if not pd.isnull(i):
            doc=nlp(i)
            reducedGold=''
            for word in doc:
                if word.tag_!='DT':
                        reducedGold=reducedGold+word.lemma_+" "
            dfs.loc[index,'reducedGold2']=reducedGold.lower()
            reducedGold4=''
            for para in dfs.loc[index,'gold2'].split():
                doc=nlp(para)
                for word in doc:
                    if word.tag_!='DT':
                        if word.text!='a' and word.text!='an' and word.text!='the':
                            answer=lemmatizer(word.text, NOUN)
                            reducedGold4=reducedGold4+answer[0]+" "
            dfs.loc[index,'reducedGold4']=reducedGold4.lower()
    dfs2=pd.read_excel("FinalDatasetAutoTextualEntailmentBaselineTop3RemoveArticleMetric.xlsx")
    dfs['HighestScorePattern']=dfs2['HighestScorePattern']
    for index,i in enumerate(dfs2['adj/noun']):
        if not pd.isnull(dfs.loc[index,'v']):
            scoreDict={}
            for pattern in dfs.loc[index,'HighestScorePattern'].split(","):
                scoreDict[pattern]=dfs.loc[index,pattern]
            dfs.loc[index,'HighestScorePattern']=max(scoreDict.items(), key=operator.itemgetter(1))[0][:-5]
        if dfs.loc[index,'HighestScorePattern']=='BVO':
            dfs.loc[index,'HighestScorePattern']='VOB'
        if dfs.loc[index,'HighestScorePattern']=='OBV':
            dfs.loc[index,'HighestScorePattern']='OVB'
    for index,i in enumerate(dfs['adj/noun']):
        #print(index)
        dfs.loc[index,'OriginalHighestScorePattern']=dfs.loc[index,'HighestScorePattern']
        if dfs.loc[index,'HighestScorePattern']=='MVpOPassive':
            pattern=dfs.loc[index,'HighestScorePattern']
            if "by" in dfs.loc[index,pattern].split():
                dfs.loc[index,'HighestScorePattern']='OVM'
            else:  
                dfs.loc[index,'HighestScorePattern']='MVpOPassiveVMpO'
        if dfs.loc[index,'HighestScorePattern']=='MpOVPassive':
                dfs.loc[index,'HighestScorePattern']='MpOVPassiveVMpO'
        if dfs.loc[index,'HighestScorePattern']=='OVpMPassive':
            pattern=dfs.loc[index,'HighestScorePattern']
            if "by" in dfs.loc[index,pattern].split():
                dfs.loc[index,'HighestScorePattern']='MVO'
            else:
                dfs.loc[index,'HighestScorePattern']='OVpMPassiveVOpM'
    for index,i in enumerate(dfs['adj/noun']):
        if not pd.isnull(dfs.loc[index,'v']):
            pattern=dfs.loc[index,'HighestScorePattern']
            if dfs.loc[index,'HighestScorePattern']!='V1' and dfs.loc[index,'HighestScorePattern']!='V2' and dfs.loc[index,'HighestScorePattern']!='M' and dfs.loc[index,'HighestScorePattern']!='originalNominalization':
                dfs.loc[index,'HighestScorePatternSentence']=dfs.loc[index,pattern]
                doc=nlp(dfs.loc[index,pattern])
                reducedParaphrase=''
                for word in doc:
                    if word.tag_!='DT':
                            reducedParaphrase=reducedParaphrase+word.lemma_+" "
                dfs.loc[index,'reducedParaphrase']=reducedParaphrase.lower()
                reducedParaphrase2=''
                for para in dfs.loc[index,pattern].split():
                    doc=nlp(para)
                    for word in doc:
                        if word.tag_!='DT':
                            if word.text!='a' and word.text!='an' and word.text!='the':
                                answer=lemmatizer(word.text, NOUN)
                                reducedParaphrase2=reducedParaphrase2+answer[0]+" "
                dfs.loc[index,'reducedParaphrase2']=reducedParaphrase2.lower()
            else:
                dfs.loc[index,'reducedParaphrase']=''
                dfs.loc[index,'reducedParaphrase2']=''
        else:
            dfs.loc[index,'reducedParaphrase']=''
            dfs.loc[index,'reducedParaphrase2']=''
    for index,i in enumerate(dfs['adj/noun']):
        if (dfs.loc[index,'reducedParaphrase']==dfs.loc[index,'reducedGold']) or (dfs.loc[index,'reducedParaphrase']==dfs.loc[index,'reducedGold2']):
            dfs.loc[index,'FinalLabel']='True'
        elif (dfs.loc[index,'reducedParaphrase2']==dfs.loc[index,'reducedGold']) or (dfs.loc[index,'reducedParaphrase2']==dfs.loc[index,'reducedGold2']) or (dfs.loc[index,'reducedParaphrase2']==dfs.loc[index,'reducedGold3']) or (dfs.loc[index,'reducedParaphrase2']==dfs.loc[index,'reducedGold4']):
            dfs.loc[index,'FinalLabel']='True'
        else:
            dfs.loc[index,'FinalLabel']='False'
    for index,i in enumerate(dfs['sentence']):
        if dfs.loc[index,'HighestScorePattern']=='M' or dfs.loc[index,'HighestScorePattern']=='VOB' or dfs.loc[index,'HighestScorePattern']=='OVB' or dfs.loc[index,'HighestScorePattern']=='V1' or dfs.loc[index,'HighestScorePattern']=='V2' or dfs.loc[index,'HighestScorePattern']=='OBV' or dfs.loc[index,'HighestScorePattern']=='BVO' or dfs.loc[index,'HighestScorePattern']=='originalNominalization':
            dfs.loc[index,'prediction2']='M'
        elif dfs.loc[index,'HighestScorePattern']=='originalNominalizationScore':
            dfs.loc[index,'prediction2']='M'
        else:
            dfs.loc[index,'prediction2']='NotM'
    for index,i in enumerate(dfs['adj/noun']):
        if (dfs.loc[index,'prediction2']=='M') and (dfs.loc[index,'adj/noun-label']=='A'):
            dfs.loc[index,'FinalLabel2']='True'
        elif (dfs.loc[index,'prediction2']=='NotM') and (dfs.loc[index,'adj/noun-label']!='A'):
            dfs.loc[index,'FinalLabel2']='True'
        else:
            dfs.loc[index,'FinalLabel2']='False'
    dfs=dfs.fillna('')
    for index,i in enumerate(dfs['adj/noun']):
        for columns in dfs.columns:
            dfs.loc[index,columns]=str(dfs.loc[index,columns])
    dfs=dfs.groupby(['adj/noun','n_v','prep','pobj'],sort=False)[dfs.columns[4:]].agg('//'.join).reset_index()
    dfs['final']=dfs['FinalLabel']
    dfs['final2']=dfs['FinalLabel2']
    dfs['finalM']=dfs['prediction2']
    for index,i in enumerate(dfs['adj/noun']):
        if 'True' in dfs.loc[index,'FinalLabel'].split("//"):
            dfs.loc[index,'FinalLabel']='True'
        else:
            dfs.loc[index,'FinalLabel']='False'
    for index,i in enumerate(dfs['adj/noun']):
        if 'True' in dfs.loc[index,'FinalLabel2'].split("//"):
            dfs.loc[index,'prediction2']=dfs.loc[index,'finalM'].split("//")[dfs.loc[index,'FinalLabel2'].split("//").index('True')]
            dfs.loc[index,'FinalLabel2']='True'
        else:
            dfs.loc[index,'prediction2']=dfs.loc[index,'finalM'].split("//")[dfs.loc[index,'FinalLabel2'].split("//").index('False')]
            dfs.loc[index,'FinalLabel2']='False'
    print(dfs['FinalLabel'].value_counts())
    print("Accuracy= "+str(dfs['FinalLabel'].value_counts()['True']/len(dfs['FinalLabel'])))
    print(dfs['FinalLabel2'].value_counts())
    print("Accuracy= "+str(dfs['FinalLabel2'].value_counts()['True']/len(dfs['FinalLabel2'])))
    resultDf.loc[num,'model']=fileName
    resultDf.loc[num,'True']=dfs['FinalLabel'].value_counts()['True']
    resultDf.loc[num,'False']=dfs['FinalLabel'].value_counts()['False']
    resultDf.loc[num,'Accuracy']=str(dfs['FinalLabel'].value_counts()['True']/len(dfs['FinalLabel']))
    dfs.to_excel("FinalDatasetAuto"+fileName+"Top3BasedTextualEntailmentRemoveArticleMetric.xlsx")
    print(len(dfs[(dfs['prediction2']=='NotM')& (dfs['FinalLabel2']=='True')]))
    print(len(dfs[(dfs['prediction2']=='NotM')]))
    print("PrecisionNotM= "+str(len(dfs[(dfs['prediction2']=='NotM')& (dfs['FinalLabel2']=='True')])/len(dfs[(dfs['prediction2']=='NotM')])))
    precisionNotM=len(dfs[(dfs['prediction2']=='NotM')& (dfs['FinalLabel2']=='True')])/len(dfs[(dfs['prediction2']=='NotM')])
    print(len(dfs[(dfs['prediction2']=='NotM')& (dfs['FinalLabel2']=='True')]))
    print((len(dfs[(dfs['prediction2']=='NotM')& (dfs['FinalLabel2']=='True')])+len(dfs[(dfs['prediction2']!='NotM')& (dfs['FinalLabel2']=='False')])))
    print("RecallNotM= "+str(len(dfs[(dfs['prediction2']=='NotM')& (dfs['FinalLabel2']=='True')])/(len(dfs[(dfs['prediction2']=='NotM')& (dfs['FinalLabel2']=='True')])+len(dfs[(dfs['prediction2']!='NotM')& (dfs['FinalLabel2']=='False')]))))
    recallNotM=len(dfs[(dfs['prediction2']=='NotM')& (dfs['FinalLabel2']=='True')])/(len(dfs[(dfs['prediction2']=='NotM')& (dfs['FinalLabel2']=='True')])+len(dfs[(dfs['prediction2']!='NotM')& (dfs['FinalLabel2']=='False')]))
    print(2 * (precisionNotM * recallNotM))
    print((precisionNotM + recallNotM))
    NotMF1=2 * (precisionNotM * recallNotM) / (precisionNotM + recallNotM)
    print("NotM F1= "+str(NotMF1))
# Out:
# GPTBaseline
# False    272
# True     104
# Name: FinalLabel, dtype: int64
# Accuracy= 0.2765957446808511
# True     252
# False    124
# Name: FinalLabel2, dtype: int64
# Accuracy= 0.6702127659574468
# 201
# 292
# PrecisionNotM= 0.6883561643835616
# 201
# 234
# RecallNotM= 0.8589743589743589
# 1.1825605900948366
# 1.5473305233579207
# NotM F1= 0.7642585551330798

# %%
dfs[(dfs['prediction2']!='NotM')& (dfs['FinalLabel2']=='False')]
# Out:
#           adj/noun            n_v     prep  \
# 4        financial     evaluation       of
# 8       diplomatic   intercession       of
# 10        physical    description       of
# 12           legal   restrictions       on
# 19   psychological     assessment       of
# 40      mechanical    maintenance       of
# 46        chemical       analysis       of
# 58          tribal        support       of
# 64      scientific  contributions       of
# 66        maritime      transport       of
# 78         nuclear         strike  against
# 84       political        effects       on
# 90         coastal      migration       of
# 95       financial    investments       of
# 97           legal        reforms       of
# 111       thematic       analysis       of
# 115     historical          study       of
# 118       climatic        effects       on
# 121          rural     settlement       by
# 122       military        reforms       of
# 147        musical      direction       of
# 152     scientific   confirmation       of
# 156     scientific   descriptions       of
# 159        musical       response       to
# 161       dogmatic     definition       of
# 185   professional    advancement       of
# 187     democratic  participation       of
# 188       physical           harm       to
# 189        ethical       behavior       of
# 211   experimental     evaluation       of
# 224       physical      movements       of
# 228       maritime     navigation       of
# 334        partial       survival       of
#
#                                                   pobj adj/noun-label  \
# 4                           customer referral programs           arg1
# 8                                    the United States             PP
# 10                                          the Buddha           arg1
# 12                                            abortion           arg0
# 19                                       an individual           arg1
# 40                                            aircraft           arg1
# 46                           Martian meteorite samples     arg1//arg1
# 58                                       the rebellion           arg0
# 64                                Muslim civilizations             PP
# 66                                               goods         PP//PP
# 78                                   the United States             PP
# 84                                   electoral systems           arg0
# 90                                              humans           arg1
# 95                                     these companies           arg1
# 97                                               Solon           arg1
# 111                                           the film     arg1//arg1
# 115                                Jehovah's Witnesses           arg1
# 118  mechanical properties of snow, ice, soil and rock           arg0
# 121                                            farmers           arg1
# 122                                       Gaius Marius           arg1
# 147                                     Claudio Abbado           arg1
# 152                                      the existence           arg0
# 156                                   dinosaur remains             PP
# 159                              these personal crises             PP
# 161                             the Tridentine Council           arg1
# 185                                  female physicists             PP
# 187                                           citizens           arg1
# 188                                        the skaters           arg1
# 189                                             robots             PP
# 211                                      spray systems             PP
# 224                                        the cellist           arg1
# 228                                             Guinea           arg1
# 334                                      Tacitus' work           arg0
#
#      pobj-label                            adj/noun.1                    arg0  \
# 4          arg1                               finance
# 8          arg0                             diplomacy       the United States
# 10         arg1                              physique
# 12         arg1                                   law                 the law
# 19         arg1                            psychology
# 40         arg1                             mechanics
# 46   arg1//arg1  chemical property//chemical property                      //
# 58         arg1                                 tribe               the tribe
# 64         arg0                               science    Muslim civilizations
# 66   arg1//arg1                            ocean//sea                      //
# 78         arg1                        nuclear weapon
# 84         arg1                              politics                politics
# 90         arg0                                 coast                  humans
# 95         arg0                                 money         these companies
# 97         arg0                                   law                   Solon
# 111  arg1//arg1                          theme//theme                      //
# 115        arg1                               history
# 118        arg1                               climate                 climate
# 121        arg0                            rural area                 farmers
# 122        arg0                              military            Gaius Marius
# 147        arg0                                 music          Claudio Abbado
# 152        arg1                               science                 science
# 156        arg1                               science
# 159        arg1                                 music
# 161        arg0                                 dogma  the Tridentine Council
# 185        arg0                      their profession       female physicists
# 187        arg0                             democracy                citizens
# 188        arg1                                  body
# 189        arg0                                ethics                  robots
# 211        arg1                            experiment
# 224        arg0                                  body             the cellist
# 228        arg1                                   sea
# 334        arg0                               partial   Part of Tacitus' work
#
#                         V                 baseV  ...  \
# 4                evaluate              evaluate  ...
# 8               intercede             intercede  ...
# 10               describe              describe  ...
# 12              restricts              restrict  ...
# 19                 assess                assess  ...
# 40               maintain              maintain  ...
# 46       analyze//analyse      analyze//analyse  ...
# 58               supports               support  ...
# 64             contribute            contribute  ...
# 66   transport//transport  transport//transport  ...
# 78                 strike                strike  ...
# 84                 affect                affect  ...
# 90                migrate               migrate  ...
# 95                 invest                invest  ...
# 97                reforms                reform  ...
# 111      analyze//analyse      analyze//analyse  ...
# 115                 study                 study  ...
# 118               affects                affect  ...
# 121                settle                settle  ...
# 122               reforms                reform  ...
# 147               directs                direct  ...
# 152              confirms               confirm  ...
# 156              describe              describe  ...
# 159               respond               respond  ...
# 161               defines                define  ...
# 185               advance               advance  ...
# 187           participate           participate  ...
# 188                  harm                  harm  ...
# 189                behave                behave  ...
# 211              evaluate              evaluate  ...
# 224                 moves                  move  ...
# 228              navigate              navigate  ...
# 334               survive               survive  ...
#
#                         OriginalHighestScorePattern  \
# 4                                               OVB
# 8                                               OVB
# 10                                              OVB
# 12                           originalNominalization
# 19                                              VOB
# 40                                              VOB
# 46                                         VOB//VOB
# 58                           originalNominalization
# 64                                              OVB
# 66   originalNominalization//originalNominalization
# 78                           originalNominalization
# 84                                              OVB
# 90                           originalNominalization
# 95                                              OVB
# 97                                              OVB
# 111                                        VOB//VOB
# 115                                             OVB
# 118                                             OVB
# 121                          originalNominalization
# 122                                             OVB
# 147                                             OVB
# 152                                             VOB
# 156                                             VOB
# 159                                             OVB
# 161                                             VOB
# 185                                             OVB
# 187                                             OVB
# 188                          originalNominalization
# 189                                             OVB
# 211                                             VOB
# 224                                             OVB
# 228                          originalNominalization
# 334                                             OVB
#
#                            HighestScorePatternSentence  \
# 4      customer referral programs evaluate financially
# 8           the United States intercede diplomatically
# 10                     the Buddha describes physically
# 12
# 19                assess an individual psychologically
# 40                      maintain aircraft mechanically
# 46   analyze Martian meteorite samples chemically//...
# 58
# 64      Muslim civilizations contribute scientifically
# 66                                                  //
# 78
# 84                electoral systems affect politically
# 90
# 95                  these companies invest financially
# 97                               Solon changes legally
# 111  analyze the film thematically//analyze the fil...
# 115             Jehovah's Witnesses study historically
# 118  mechanical properties of snow, ice, soil and r...
# 121
# 122                    Gaius Marius reforms militarily
# 147                   Claudio Abbado directs musically
# 152               confirm the existence scientifically
# 156           describe dinosaur remains scientifically
# 159            these personal crises respond musically
# 161         define the Tridentine Council dogmatically
# 185           female physicists advance professionally
# 187                citizens participate democratically
# 188
# 189                            robots behave ethically
# 211              evaluate spray systems experimentally
# 224                       the cellist moves physically
# 228
# 334                   Tacitus' work survives partially
#
#                                      reducedParaphrase  \
# 4      customer referral program evaluate financially
# 8              united states intercede diplomatically
# 10                         buddha describe physically
# 12
# 19                  assess individual psychologically
# 40                     maintain aircraft mechanically
# 46   analyze martian meteorite sample chemically //...
# 58
# 64      muslim civilization contribute scientifically
# 66                                                  //
# 78
# 84                electoral system affect politically
# 90
# 95                         company invest financially
# 97                               solon change legally
# 111  analyze film thematically //analyze film thema...
# 115             jehovah 's witness study historically
# 118  mechanical property of snow , ice , soil and r...
# 121
# 122                    gaius marius reform militarily
# 147                   claudio abbado direct musically
# 152                  confirm existence scientifically
# 156           describe dinosaur remain scientifically
# 159                 personal crisis respond musically
# 161            define tridentine council dogmatically
# 185           female physicist advance professionally
# 187                citizen participate democratically
# 188
# 189                            robot behave ethically
# 211              evaluate spray system experimentally
# 224                           cellist move physically
# 228
# 334                  tacitus ' work survive partially
#
#                                     reducedParaphrase2 FinalLabel prediction2  \
# 4      customer referral program evaluate financially       False           M
# 8               united state intercede diplomatically       False           M
# 10                         buddha describe physically       False           M
# 12                                                          False           M
# 19                   asses individual psychologically       False           M
# 40                     maintain aircraft mechanically       False           M
# 46   analyze martian meteorite sample chemically //...      False           M
# 58                                                          False           M
# 64      muslim civilization contribute scientifically       False           M
# 66                                                  //      False           M
# 78                                                          False           M
# 84                electoral system affect politically       False           M
# 90                                                          False           M
# 95                         company invest financially       False           M
# 97                               solon change legally       False           M
# 111  analyze film thematically //analyze film thema...      False           M
# 115              jehovah ' witness study historically       False           M
# 118  mechanical property of snow , ice , soil and r...      False           M
# 121                                                         False           M
# 122                      gaiu mariu reform militarily       False           M
# 147                   claudio abbado direct musically       False           M
# 152                  confirm existence scientifically       False           M
# 156           describe dinosaur remain scientifically       False           M
# 159                 personal crisis respond musically       False           M
# 161            define tridentine council dogmatically       False           M
# 185           female physicist advance professionally       False           M
# 187                citizen participate democratically       False           M
# 188                                                         False           M
# 189                            robot behave ethically       False           M
# 211              evaluate spray system experimentally       False           M
# 224                           cellist move physically       False           M
# 228                                                         False           M
# 334                   tacitu ' work survive partially       False           M
#
#     FinalLabel2         final        final2 finalM
# 4         False         False         False      M
# 8         False         False         False      M
# 10        False         False         False      M
# 12        False         False         False      M
# 19        False         False         False      M
# 40        False         False         False      M
# 46        False  False//False  False//False   M//M
# 58        False         False         False      M
# 64        False         False         False      M
# 66        False  False//False  False//False   M//M
# 78        False         False         False      M
# 84        False         False         False      M
# 90        False         False         False      M
# 95        False         False         False      M
# 97        False         False         False      M
# 111       False  False//False  False//False   M//M
# 115       False         False         False      M
# 118       False         False         False      M
# 121       False         False         False      M
# 122       False         False         False      M
# 147       False         False         False      M
# 152       False         False         False      M
# 156       False         False         False      M
# 159       False         False         False      M
# 161       False         False         False      M
# 185       False         False         False      M
# 187       False         False         False      M
# 188       False         False         False      M
# 189       False         False         False      M
# 211       False         False         False      M
# 224       False         False         False      M
# 228       False         False         False      M
# 334       False         False         False      M
#
# [33 rows x 78 columns]
